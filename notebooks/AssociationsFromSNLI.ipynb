# %% [markdown]
# # Comparing Free Association Norms to SNLI-derived association

# %% [markdown]
# This notebook uses Peter's DT-RNN model trained on the SNLI data set to predict one-word entailments for words in the Free Association Norms dataset. Only those words that are contained in both the SNLI dataset and the Free Association Norms are analyzed. Over 80% of words in norms are also present in the SNLI dataset.
#
# Premature conclusion: One word entailings produce a word that is associate of a given word in less than 10% of tested cases. Reasons as to why this is the case are outlined at the end of this notebook.

# %%
import pysem
import pickle

from collections import namedtuple
from pysem.corpora import SNLI
from pysem.networks import DependencyNetwork
from pysem.generatives import EmbeddingGenerator, EncoderDecoder

# %% [markdown]
# Loading the DT-RNN model pretrained on the SNLI dataset:

# %%
TrainingPair = namedtuple('TrainingPair', ['sentence1', 'sentence2', 'label'])  # needed for pickle

with open('../data/train_data.pickle', 'rb') as pfile:
    train_data = pickle.load(pfile)
    
with open('../data/vocab.pickle', 'rb') as pfile:
    vocab_snli = pickle.load(pfile)
    
model = EncoderDecoder(encoder=None, decoder=None, data=train_data)
model.load('enc_model_0006_alt.pickle','dec_model_0006_alt.pickle')

# %% [markdown]
# Loading free-associations:

# %%
import sparat
path = '/home/ivana/phd/workspace/sparat/data/associationmatrices/'
name = 'freeassoc_asymmetric'

# %% [markdown]
# Load one vocabulary containig all words in Free Norms, and another one with animal words:

# %%
mat, vocab_free_full, w2i = sparat.load_assoc_mat(path, name)
vocab_free_animals = [w.lower().strip() for w in open('../data/animal_words.txt','r').readlines()]

vocab_snli = [w.lower() for w in vocab_snli]
vocab_free_full = [w.lower() for w in vocab_free_full]

# %%
print(vocab_free_full[:6])
print(vocab_free_animals[:4])
# Out:
# ['stairway', 'life', 'unsure', 'loft', 'tease', 'flow']
# ['aardvark', 'alligator', 'ant', 'anteater']

# %% [markdown]
# ### Comparisons of vocabulary sizes

# %% [markdown]
# Show the number of words in all vocabularies (SNLI, norms all, norms animals):

# %%
print('Total number of words in a vocabulary\n---')
print('SNLI vocab:', len(np.unique(vocab_snli)))
print('Free associations vocab:', len(vocab_free_full))
print('Animals in free associations vocab:', len(vocab_free_animals))
# Out:
# Total number of words in a vocabulary
# ---
# SNLI vocab: 19306
# Free associations vocab: 5018
# Animals in free associations vocab: 158

# %% [markdown]
# The SNLI vocabulary has almost four times more words, but many of those are non-words like different numbers (1.9, 100th), expressions (100-meter, 12-hour), random words (ab, abc. ) and various grammatical forms of the same word. In other words, it contains a lot of noise.
#
# Now let's compare the number of words contained in both vocabularies:

# %%
words_overlap = list(set(vocab_free_full) & set(vocab_snli))
print('Number of words found in free norms vocab and in SNLI vocab:', len(words_overlap))

animals_overlap = list(set(vocab_free_animals) & set(vocab_snli))
print('Number of animals in both datasets:', len(animals_overlap))
# Out:
# Number of words found in free norms vocab and in SNLI vocab: 4208
# Number of animals in both datasets: 146

# %%
print('Words in free norms but not in SNLI:', len(set(vocab_free_full) - set(vocab_snli)))
# Out:
# Words in free norms but not in SNLI: 810

# %% [markdown]
# About 15% of words in Norms are not present in the SNLI vocabulary. Eyeballing the data, looks like a lot of words related to food and animals are not included, any words with potentially promiment affective connotations as well as more technical/domain-specific terminology (eg. in economics, medicine, law).

# %%
set(vocab_free_full)-set(vocab_snli)
# Out:
# {'aardvark',
#  'abnormal',
#  'absurd',
#  'abundance',
#  'accelerate',
#  'accept',
#  'accuse',
#  'ache',
#  'acre',
#  'adjective',
#  'adjourn',
#  'admit',
#  'adore',
#  'adultery',
#  'adverb',
#  'advil',
#  'affect',
#  'agenda',
#  'aggravate',
#  'ahoy',
#  'air force',
#  'almanac',
#  'almond',
#  'amaze',
#  'ambition',
#  'ancestor',
#  'anisette',
#  'annihilate',
#  'announce',
#  'anteater',
#  'antidote',
#  'antler',
#  'antlers',
#  'anxiety',
#  'apology',
#  'appeal',
#  'appraise',
#  'aright',
#  'aroma',
#  'arrogant',
#  'artery',
#  'ashes',
#  'atlas',
#  'atomic',
#  'aura',
#  'axon',
#  'backbone',
#  'bandaid',
#  'bargain',
#  'barley',
#  'barracuda',
#  'bashful',
#  'beet',
#  'betray',
#  'beware',
#  'bias',
#  'bizarre',
#  'blackmail',
#  'blame',
#  'blockade',
#  'blonde',
#  'blot',
#  'blubber',
#  'bluejay',
#  'bold',
#  'bologna',
#  'bookbag',
#  'bother',
#  'bouillon',
#  'bounty',
#  'bran',
#  'bravado',
#  'breakable',
#  'bribe',
#  'bristle',
#  'britannica',
#  'bullock',
#  'bureau',
#  'cafe',
#  'caffeine',
#  'calcium',
#  'canary',
#  'capability',
#  'cardinal',
#  'cashew',
#  'cauliflower',
#  'celsius',
#  'cent',
#  'chairperson',
#  'characteristic',
#  'checkbook',
#  'cheddar',
#  'chemist',
#  'chime',
#  'chimpanzee',
#  'chirp',
#  'chowder',
#  'chromosomes',
#  'circumstance',
#  'clamp',
#  'clarify',
#  'clench',
#  'click',
#  'clog',
#  'clorox',
#  'co-pilot',
#  'cobbler',
#  'cobra',
#  'cobweb',
#  'coca-cola',
#  'coleslaw',
#  'comma',
#  'committee',
#  'competence',
#  'components',
#  'compose',
#  'compulsion',
#  'compute',
#  'conceit',
#  'conceited',
#  'condemn',
#  'confess',
#  'conquer',
#  'conscience',
#  'consequence',
#  'constant',
#  'constitution',
#  'context',
#  'cornbeef',
#  'corporal',
#  'corporation',
#  'corrupt',
#  'counsel',
#  'crave',
#  'crayola',
#  'crease',
#  'creator',
#  'crisis',
#  'criterion',
#  'critical',
#  'criticism',
#  'criticize',
#  'croak',
#  'cunning',
#  'curiosity',
#  'cuss',
#  'custard',
#  'dandruff',
#  'deceit',
#  'deceive',
#  'decency',
#  'deception',
#  'decompose',
#  'decrease',
#  'define',
#  'definition',
#  'defrost',
#  'degrade',
#  'delinquent',
#  'demi',
#  'democracy',
#  'denial',
#  'dent',
#  'deodorant',
#  'depend',
#  'dependent',
#  'depletion',
#  'depression',
#  'deputy',
#  'deteriorate',
#  'dial',
#  'diameter',
#  'digest',
#  'digestion',
#  'digit',
#  'dignity',
#  'dilemma',
#  'diligence',
#  'dill',
#  'diminish',
#  'disallow',
#  'disappear',
#  'disappoint',
#  'disbelieve',
#  'discomfort',
#  'discourage',
#  'discreet',
#  'disgrace',
#  'dishonest',
#  'disintegrate',
#  'dismiss',
#  'disorder',
#  'disown',
#  'disprove',
#  'dissimilar',
#  'dissolve',
#  'divide',
#  'donor',
#  'doubt',
#  'doughnut',
#  'drowsy',
#  'dungeon',
#  'duplicate',
#  'dwarves',
#  'dynasty',
#  'earnestness',
#  'editorial',
#  'ego',
#  'elect',
#  'electron',
#  'embarrass',
#  'encyclopedia',
#  'endless',
#  'enrage',
#  'eraser',
#  'erode',
#  'escargot',
#  'esteem',
#  'eternal',
#  'ethics',
#  'evacuate',
#  'evict',
#  'ewe',
#  'excedrin',
#  'excel',
#  'exceptional',
#  'excise',
#  'exclamation point',
#  'excuse',
#  'exhale',
#  'existence',
#  'explanation',
#  'extension',
#  'extremity',
#  'factor',
#  'faculty',
#  'fad',
#  'fade',
#  'fascism',
#  'fattening',
#  'fawn',
#  'feeble',
#  'feud',
#  'fib',
#  'fin',
#  'flake',
#  'flex',
#  'flick',
#  'flipper',
#  'flunk',
#  'flush',
#  'follower',
#  'folly',
#  'forbid',
#  'forbidden',
#  'foresight',
#  'forgive',
#  'fracture',
#  'fragile',
#  'fragrance',
#  'frail',
#  'frantic',
#  'fray',
#  'freckle',
#  'frequency',
#  'friar',
#  'frill',
#  'frustrate',
#  'fungi',
#  'fury',
#  'fuss',
#  'fuzz',
#  'gag',
#  'gallop',
#  'gander',
#  'gauge',
#  'gauze',
#  'gem',
#  'gene',
#  'genuine',
#  'geometry',
#  'germ',
#  'ghoul',
#  'gifted',
#  'give up',
#  'glands',
#  'godliness',
#  'goodness',
#  'graft',
#  'grammar',
#  'grant',
#  'grit',
#  'grown-ups',
#  'guardian',
#  'guess',
#  'guilt',
#  'guilty',
#  'gullible',
#  'gully',
#  'gums',
#  'hallucination',
#  'hardy',
#  'haughty',
#  'haven',
#  'havoc',
#  'haze',
#  'head & shoulders',
#  'heart attack',
#  'heater',
#  'hem',
#  'hen',
#  'heroine',
#  'hesitate',
#  'high school',
#  'hindsight',
#  'hinge',
#  'hint',
#  'holiness',
#  'honesty',
#  'hormones',
#  'hostility',
#  'hot dogs',
#  'hotter',
#  'hum',
#  'humiliate',
#  'hydrogen',
#  'hypnotize',
#  'ice cream',
#  'idiot',
#  'illusion',
#  'imagine',
#  'immoral',
#  'impatience',
#  'implode',
#  'impression',
#  'impulse',
#  'inability',
#  'incorrect',
#  'indirect',
#  'inexpensive',
#  'infection',
#  'inferior',
#  'infinite',
#  'inflation',
#  'initial',
#  'inquire',
#  'insight',
#  'instance',
#  'instinct',
#  'insult',
#  'integrate',
#  'intellect',
#  'intelligent',
#  'interrupt',
#  'intestine',
#  'intoxicate',
#  'introvert',
#  'intuition',
#  'invalid',
#  'invent',
#  'ivory',
#  'jealousy',
#  'jewel',
#  'jobless',
#  'jock',
#  'judgment',
#  'justify',
#  'kindness',
#  'kinetic',
#  'kleenex',
#  'knapsack',
#  'knuckle',
#  'lash',
#  'latch',
#  'lather',
#  'lawful',
#  'lawsuit',
#  'leadership',
#  'learner',
#  'legion',
#  'legislature',
#  'lenient',
#  'leo',
#  'liar',
#  'libel',
#  'liberal',
#  'lieutenant',
#  'lifestyle',
#  'lightheaded',
#  'likelihood',
#  'living room',
#  'lobe',
#  'logic',
#  'loosen',
#  'los angeles',
#  'loyalty',
#  'lubricate',
#  'lust',
#  'mafia',
#  'maggot',
#  'magnitude',
#  'make up',
#  'malaria',
#  'manufacturer',
#  'margarine',
#  'margin',
#  'marrow',
#  'mash',
#  'mastery',
#  'mayonnaise',
#  "mcdonald's",
#  'measurement',
#  'mediocre',
#  'meek',
#  'meow',
#  'merit',
#  'meteorite',
#  'meticulous',
#  'metric',
#  'migraine',
#  'mildew',
#  'minded',
#  'mineral',
#  'minority',
#  'mints',
#  'minus',
#  'mischief',
#  'misery',
#  'missile',
#  'mister',
#  'mistreat',
#  'modest',
#  'molasses',
#  'monarchy',
#  'monotonous',
#  'moral',
#  'morals',
#  'moron',
#  'morse',
#  'mortgage',
#  'muck',
#  'multiply',
#  'mummy',
#  'musty',
#  'mutton',
#  'myth',
#  'mythology',
#  'nag',
#  'naive',
#  'nausea',
#  'nauseous',
#  'negotiation',
#  'neptune',
#  'nerve',
#  'neuron',
#  'neutron',
#  'new year',
#  'new york',
#  'newton',
#  'nickel',
#  'nomad',
#  'nonsense',
#  'noose',
#  'norm',
#  'notify',
#  'notion',
#  'noun',
#  'nucleus',
#  'nylons',
#  'obey',
#  'obligation',
#  'obsession',
#  'odds',
#  'offend',
#  'ointment',
#  'oligarchy',
#  'oodles',
#  'opener',
#  'optimistic',
#  'orange juice',
#  'orchid',
#  'oregano',
#  'originate',
#  'orthodontist',
#  'ouch',
#  'ounce',
#  'out fox',
#  'outgoing',
#  'outlaw',
#  'overcome',
#  'overpower',
#  'overwhelm',
#  'owe',
#  'ozone',
#  'paper towel',
#  'paperclip',
#  'paragraph',
#  'parkway',
#  'parsley',
#  'pass out',
#  'patriot',
#  'peanut butter',
#  'pelt',
#  'pendulum',
#  'perceive',
#  'perception',
#  'perjury',
#  'peroxide',
#  'perspire',
#  'persuade',
#  'pest',
#  'petroleum',
#  'phase',
#  'phony',
#  'phrase',
#  'physiology',
#  'pick up',
#  'pill',
#  'pimple',
#  'pinch',
#  'pissed',
#  'piston',
#  'pity',
#  'play dough',
#  'plaything',
#  'plum',
#  'poach',
#  'poise',
#  'polyester',
#  'popeye',
#  'portray',
#  'possibility',
#  'postage',
#  'precise',
#  'predict',
#  'preference',
#  'prejudice',
#  'prestige',
#  'preview',
#  'prick',
#  'prickly',
#  'prim',
#  'primate',
#  'principle',
#  'prism',
#  'probability',
#  'producer',
#  'prohibit',
#  'promise',
#  'pronoun',
#  'proprietor',
#  'prose',
#  'prosecute',
#  'prosper',
#  'protestant',
#  'proton',
#  'protractor',
#  'proverb',
#  'providence',
#  'provision',
#  'psalm',
#  'puberty',
#  'publisher',
#  'pun',
#  'punctuation',
#  'pupil',
#  'put down',
#  'q-tips',
#  'quack',
#  'quarrel',
#  'quill',
#  'quiver',
#  'quotient',
#  'racquet',
#  'radiator',
#  'radish',
#  'raisin',
#  'rank',
#  'rape',
#  'rash',
#  'rationalize',
#  'real estate',
#  'reap',
#  'rearrange',
#  'recall',
#  'recommend',
#  'recommendation',
#  'refrain',
#  'regulation',
#  'regulations',
#  'reject',
#  'relation',
#  'relativity',
#  'reliable',
#  'relish',
#  'rely',
#  'remark',
#  'remind',
#  'reminiscence',
#  'remorse',
#  'remover',
#  'renounce',
#  'repentance',
#  'repress',
#  'reprimand',
#  'reproduce',
#  'repulsive',
#  'reservation',
#  'reserve',
#  'responsibility',
#  'restriction',
#  'retain',
#  'retarded',
#  'rhyme',
#  'riddle',
#  'ridicule',
#  'righteous',
#  'righteousness',
#  'rigid',
#  'rinse',
#  'roost',
#  'rot',
#  'rouge',
#  'rumor',
#  'sage',
#  'saltine',
#  'sandpaper',
#  'sapphire',
#  'sardine',
#  'savior',
#  'scallop',
#  'scapegoat',
#  'scarcity',
#  'scheme',
#  'scrambled',
#  'scribble',
#  'scroll',
#  'scum',
#  'seam',
#  'secretive',
#  'sedative',
#  'seize',
#  'seldom',
#  'selfish',
#  'senate',
#  'sensitive',
#  'sentry',
#  'serpent',
#  'shiver',
#  'shrink',
#  'shun',
#  'sincere',
#  'sincerity',
#  'sinker',
#  'sinus',
#  'sirloin',
#  'slander',
#  'slay',
#  'slither',
#  'slob',
#  'slurp',
#  'sly',
#  'smelt',
#  'smog',
#  'snob',
#  'snore',
#  'snotty',
#  'sob',
#  'socket',
#  'soft drink',
#  'sonnet',
#  'span',
#  'spine',
#  'spoil',
#  'spontaneous',
#  'spook',
#  'standards',
#  'starboard',
#  'starch',
#  'stench',
#  'stereotype',
#  'stiff',
#  'stimulus',
#  'stingy',
#  'stopper',
#  'strive',
#  'stub',
#  'stubborn',
#  'stuck up',
#  'stud',
#  'sty',
#  'subjective',
#  'subtlety',
#  'subtract',
#  'subtraction',
#  'succor',
#  'suffocate',
#  'suggestion',
#  'summary',
#  'superstition',
#  'suppose',
#  'suspense',
#  'swabs',
#  'swatter',
#  'swoon',
#  'sympathetic',
#  'symptom',
#  'synopsis',
#  'taboo',
#  'tact',
#  'tactful',
#  'tampa',
#  'tangent',
#  'tangerine',
#  'tangy',
#  'tapioca',
#  'tardy',
#  'tarnish',
#  'tendency',
#  'tension',
#  'termite',
#  'terms',
#  'terrific',
#  'test tube',
#  'thaw',
#  'theorem',
#  'thesaurus',
#  'thorn',
#  'thriller',
#  'throw up',
#  'tick',
#  'toasty',
#  'tone',
#  'tonic',
#  'torture',
#  'touchy',
#  'trace',
#  'traitor',
#  'tramp',
#  'trance',
#  'trauma',
#  'treason',
#  'treble',
#  'trigger',
#  'truce',
#  'trust',
#  'trustworthy',
#  'truthful',
#  'tupperware',
#  'turnip',
#  'tweezers',
#  'twinkle',
#  'tylenol',
#  'typhoon',
#  'typist',
#  'ulcer',
#  'undecided',
#  'uneasy',
#  'unequal',
#  'unjust',
#  'unsolved',
#  'untrue',
#  'untruthful',
#  'useless',
#  'usurp',
#  'vacancy',
#  'vacate',
#  'vagrant',
#  'vague',
#  'valor',
#  'vanish',
#  'vaseline',
#  'veal',
#  'veer',
#  'vein',
#  'venom',
#  'verb',
#  'vice',
#  'vinegar',
#  'virtue',
#  'vocabulary',
#  'volt',
#  'vulnerable',
#  'wag',
#  'wager',
#  'walnut',
#  'wart',
#  'washcloth',
#  'watt',
#  'weakness',
#  'welfare',
#  'well-being',
#  'wick',
#  'width',
#  'wiggle',
#  'wigwam',
#  'wimp',
#  'wisdom',
#  'withdrawn',
#  'worthless',
#  'wrinkle',
#  'xerox',
#  'yearn',
#  'yo-yo',
#  'yolk',
#  'yours',
#  'yuck',
#  'zenith',
#  'zest',
#  'zit'}

# %% [markdown]
# ## Generating one-word entailments

# %% [markdown]
# We use Pete's trained model and explore what comes out at the side of decoder when a single word is presented. First testing frequent words:

# %%
words = ['cat','dog', 'fish', 'octopus', 'eat', 'mother', 'son', 'book', 'happiness', 
         'luck','when', 'why', 'how', 'eat', 'banana']

for word in words:
    assert word in words_overlap, word + ' not in one of the vocabularies'

# %%
print('Encoded -> Decoded:\n---')
for word in words:
    model.encode(word)
    print(word, '->', model.decode('dog is similar to cat'))
# Out:
# Encoded -> Decoded:
# ---
# cat -> cat cat furry with cat
# dog -> dog dog leashed with dog
# fish -> fish fish fishing near fish
# octopus -> octopus whale whale underwater octopus
# eat -> eating eat eating of eat
# mother -> mother mother distraught with mother
# son -> father son newborn than son
# book -> book book paperback about book
# happiness -> marriage affection happy in happiness
# luck -> fortune gamble lucky of luck
# when -> it later about about other
# why -> what answer sad about reasons
# how -> what react about about importance
# eat -> eating eat eating of eat
# banana -> banana banana nutritious of banana

# %% [markdown]
# It appears that the very frequent words are just repetitions of themelves (cat->cat, dog->dog). The situation gets a bit more interesting when inspecting less frequent words and interrogative words.
#
# We now analyse in how many cases the entailed word appears in the list of associates for a given word

# %%
def get_assoc(word,top=1):
    word = word.upper()
    row = mat[w2i[word]]
    row[w2i[word]] = 0 # auto-assoc
    if top == 1:
        idx = np.argmax(row)
        return vocab_free_full[idx].lower()
    else:
        non_zeros = len(np.nonzero(row)[0])
        idx = np.argsort(row)[-non_zeros:]
        return [vocab_free_full[i].lower() for i in idx[::-1]]

counter = 0
for word in words_overlap:
    model.encode(word)
    decoded=model.decode('word')
    #if word!=decoded and word+'ing'!=decoded:
    #    print(word, ',',  decoded, ',', get_strongest_assoc(word))
    if word!=decoded:
        #print(word, '->', decoded)
        list_assoc = get_assoc(word, 0)
        if decoded in list_assoc:
            print('Encoded word:', word)
            print('Decoded:', decoded)
            print('Associates:', list_assoc, '\n')
            counter += 1
# Out:
# Encoded word: daisy
# Decoded: flower
# Associates: ['flower', 'yellow', 'rose', 'petals', 'gun', 'dog', 'tulip', 'girl']
#
# Encoded word: luck
# Decoded: gamble
# Associates: ['good', 'charm', 'bad', 'chance', 'fortune', 'never', 'skill', 'happiness', 'gamble']
#
# Encoded word: topic
# Decoded: discussion
# Associates: ['subject', 'idea', 'title', 'paper', 'thesis', 'story', 'sentence', 'discussion', 'theme', 'book', 'study', 'meaning', 'issue', 'main', 'conversation']
#
# Encoded word: expense
# Decoded: cost
# Associates: ['money', 'account', 'cost', 'bill', 'pay', 'cheap', 'price', 'clothes', 'car', 'book', 'food', 'school', 'broke', 'buy']
#
# Encoded word: beans
# Decoded: peas
# Associates: ['rice', 'food', 'gas', 'vegetables', 'pork', 'green', 'baked', 'hot dogs', 'black', 'chili', 'peas', 'cool', 'soup', 'potatoes']
#
# Encoded word: basement
# Decoded: cellar
# Associates: ['attic', 'cellar', 'bottom', 'house', 'dark', 'cold', 'stairs', 'floor', 'underground', 'downstairs', 'below', 'low', 'under', 'cement', 'north', 'odor', 'scary', 'dirty', 'home']
#
# Encoded word: moat
# Decoded: pond
# Associates: ['castle', 'water', 'boat', 'river', 'swamp', 'lake', 'alligator', 'canal', 'mud', 'bridge', 'pond', 'monster', 'dragon', 'england']
#
# Encoded word: hairy
# Decoded: bald
# Associates: ['ape', 'bald', 'fuzzy', 'gross', 'dog', 'legs', 'chest', 'furry', 'arms', 'man', 'bear', 'smooth', 'gorilla', 'ugly', 'monster', 'shave', 'long', 'back', 'monkey', 'animal', 'hair', 'beast', 'black', 'dirty', 'yuck']
#
# Encoded word: utensil
# Decoded: knife
# Associates: ['fork', 'tool', 'spoon', 'kitchen', 'cooking', 'knife', 'spatula', 'pen', 'pan', 'instrument', 'silverware']
#
# Encoded word: unpleasant
# Decoded: rude
# Associates: ['bad', 'pleasant', 'mean', 'odor', 'unhappy', 'gross', 'smell', 'dislike', 'nice', 'nasty', 'uncomfortable', 'sad', 'pain', 'taste', 'foul', 'dirty', 'school', 'hurt', 'rude', 'awful']
#
# Encoded word: sermon
# Decoded: lecture
# Associates: ['church', 'preacher', 'lecture', 'priest', 'speech', 'mass', 'fish', 'bible']
#
# Encoded word: equal
# Decoded: fair
# Associates: ['same', 'rights', 'sugar', 'unequal', 'even', 'fair', 'sum', 'opportunity', 'opposite', 'amount', 'uneven', 'exact', 'alike', 'less']
#
# Encoded word: scent
# Decoded: smell
# Associates: ['smell', 'perfume', 'odor', 'aroma', 'fragrance', 'nose']
#
# Encoded word: motel
# Decoded: hotel
# Associates: ['hotel', 'sleep', 'sex', 'room', 'vacation', 'cheap', 'roach', 'night', 'travel', 'small', 'sign', 'vacancy']
#
# Encoded word: crystal
# Decoded: vase
# Associates: ['ball', 'glass', 'clear', 'diamond', 'vase', 'jewelry', 'fragile', 'expensive', 'magic', 'china', 'necklace', 'jewel', 'pretty']
#
# Encoded word: pie
# Decoded: cake
# Associates: ['apple', 'cake', 'cherry', 'eat', 'piece', 'face', 'chocolate', 'ice cream', 'cream', 'pumpkin', 'crust', 'blueberry', 'hair', 'dessert', 'food', 'pudding', 'sky', 'slice', 'bake', 'fat']
#
# Encoded word: task
# Decoded: chore
# Associates: ['job', 'work', 'chore', 'force', 'duty', 'hard', 'do', 'burden', 'assignment', 'mission']
#
# Encoded word: cucumber
# Decoded: salad
# Associates: ['pickles', 'vegetables', 'salad', 'green', 'tomato', 'garden', 'cool', 'zucchini']
#
# Encoded word: short
# Decoded: long
# Associates: ['tall', 'long', 'small', 'fat', 'story', 'people', 'skirt']
#
# Encoded word: bouquet
# Decoded: flowers
# Associates: ['flowers', 'roses', 'eat']
#
# Encoded word: foot
# Decoded: feet
# Associates: ['shoe', 'toe', 'hand', 'ball', 'leg', 'feet', 'big', 'walk', 'inch']
#
# Encoded word: dew
# Decoded: rain
# Associates: ['wet', 'morning', 'water', 'grass', 'moist', 'rain', 'drop', 'mountain', 'mist', 'fog', 'frost', 'damp', 'flower']
#
# Encoded word: flakes
# Decoded: snow
# Associates: ['corn', 'snow', 'frosted', 'dandruff', 'cereal', 'hair']
#
# Encoded word: lazy
# Decoded: tired
# Associates: ['tired', 'bum', 'sleep', 'slow', 'energetic', 'fat', 'boy', 'bored', 'hammock', 'relax', 'energy', 'active', 'worthless', 'work', 'dog', 'ambition', 'slob', 'busy', 'weekend']
#
# Encoded word: pork
# Decoded: meat
# Associates: ['pig', 'chop', 'roast', 'beef', 'ham', 'meat', 'hog', 'bacon', 'beans']
#
# Encoded word: shorts
# Decoded: pants
# Associates: ['pants', 'shirt', 'summer', 'legs', 'skirt', 'clothes', 'cool', 'warm', 'sun', 'boxer', 'hot', 'top', 'long', 'jeans', 'heat']
#
# Encoded word: jeans
# Decoded: pants
# Associates: ['pants', 'blue', 'denim', 'shirt', 'tight', 'casual', 'slacks', 'guess', 'shorts', 'jacket']
#
# Encoded word: oar
# Decoded: paddle
# Associates: ['boat', 'row', 'paddle', 'canoe', 'man']
#
# Encoded word: novel
# Decoded: book
# Associates: ['book', 'read', 'idea', 'story', 'long', 'fiction']
#
# Encoded word: anatomy
# Decoded: biology
# Associates: ['body', 'physiology', 'science', 'biology', 'doctor', 'arm', 'human', 'medicine', 'medical', 'class', 'frog', 'sex']
#
# Encoded word: temperature
# Decoded: heat
# Associates: ['hot', 'heat', 'degree', 'cold', 'climate', 'warm', 'thermometer', 'weather', 'fever', 'celsius', 'cool']
#
# Encoded word: stove
# Decoded: kitchen
# Associates: ['hot', 'oven', 'cook', 'top', 'heat', 'kitchen', 'pipe', 'range', 'warm', 'cooking']
#
# Encoded word: growth
# Decoded: grow
# Associates: ['tall', 'plant', 'height', 'child', 'age', 'big', 'development', 'mature', 'tree', 'old', 'strength', 'plate', 'stimulus', 'decay', 'baby', 'kids', 'shrink', 'up', 'grow']
#
# Encoded word: gull
# Decoded: seagull
# Associates: ['bird', 'sea', 'ocean', 'beach', 'fly', 'wings', 'seagull', 'freedom']
#
# Encoded word: saint
# Decoded: priest
# Associates: ['angel', 'church', 'god', 'holy', 'good', 'catholic', 'heaven', 'religion', 'christian', 'mary', 'priest']
#
# Encoded word: gas
# Decoded: fuel
# Associates: ['car', 'fuel', 'money', 'oil', 'station', 'petroleum', 'stove', 'expensive', 'energy', 'heat']
#
# Encoded word: zebra
# Decoded: giraffe
# Associates: ['stripe', 'horse', 'animal', 'zoo', 'africa', 'donkey', 'jungle', 'elephant', 'giraffe']
#
# Encoded word: national
# Decoded: country
# Associates: ['country', 'usa', 'world', 'american', 'state', 'flag', 'local', 'known', 'big', 'guard', 'government', 'news', 'park', 'security', 'baseball', 'league']
#
# Encoded word: cloth
# Decoded: fabric
# Associates: ['material', 'clothes', 'fabric', 'sew', 'cotton', 'silk', 'pants', 'soft', 'rag', 'wash', 'wear', 'shirt', 'towel', 'world', 'table', 'dish', 'warmth', 'clean', 'cover', 'coat', 'wipe']
#
# Encoded word: extravagant
# Decoded: elaborate
# Associates: ['rich', 'beautiful', 'expensive', 'fancy', 'elegant', 'wild', 'simple', 'grand', 'big', 'elaborate', 'large', 'generous', 'party', 'wonderful', 'lots']
#
# Encoded word: beef
# Decoded: meat
# Associates: ['cow', 'meat', 'roast', 'steak', 'hamburger', 'stew', 'cattle', 'pork', 'eat', 'turkey']
#
# Encoded word: remedy
# Decoded: fix
# Associates: ['cure', 'medicine', 'solution', 'sick', 'fix', 'cold', 'ill', 'relief', 'cause', 'healthy']
#
# Encoded word: navigator
# Decoded: sailor
# Associates: ['pilot', 'ship', 'airplane', 'boat', 'sailor', 'sea', 'leader', 'director', 'flight', 'captain', 'guide', 'driver', 'steer']
#
# Encoded word: several
# Decoded: few
# Associates: ['many', 'few', 'lots', 'people', 'some', 'numerous', 'hours', 'more', 'times', 'couple', 'two']
#
# Encoded word: oak
# Decoded: wood
# Associates: ['tree', 'maple', 'wood', 'acorn', 'leaf', 'elm', 'huge', 'pine', 'beauty']
#
# Encoded word: hatchet
# Decoded: knife
# Associates: ['ax', 'knife', 'tool', 'hammer', 'cut', 'chop', 'weapon', 'saw', 'blood', 'kill', 'murder', 'bury']
#
# Encoded word: convict
# Decoded: prison
# Associates: ['jail', 'criminal', 'prison', 'prisoner', 'escape', 'killer', 'crime', 'guilty', 'trial', 'arrest', 'appeal', 'murderer', 'crook', 'villain', 'sentence', 'thief']
#
# Encoded word: galoshes
# Decoded: boots
# Associates: ['rain', 'boots', 'wet', 'shoe', 'snow', 'rubber', 'mud']
#
# Encoded word: grain
# Decoded: corn
# Associates: ['wheat', 'sand', 'rice', 'corn', 'salt', 'food', 'alcohol', 'bread', 'seed', 'cereal', 'oats']
#
# Encoded word: organ
# Decoded: instrument
# Associates: ['piano', 'donor', 'heart', 'body', 'music', 'church', 'tissue', 'instrument', 'transplant', 'play', 'kidney']
#
# Encoded word: manners
# Decoded: rude
# Associates: ['polite', 'etiquette', 'table', 'good', 'rude', 'behavior', 'bad', 'kind', 'proper', 'morals', 'nice', 'dinner', 'eating']
# Encoded word: spade
# Decoded: shovel
# Associates: ['cards', 'shovel', 'ace', 'dig', 'garden', 'black', 'dog', 'dirt', 'hoe', 'diamond', 'tool', 'heart']
#
# Encoded word: reptile
# Decoded: alligator
# Associates: ['snake', 'lizard', 'alligator', 'scales', 'mammal', 'animal', 'gross', 'frog']
#
# Encoded word: creek
# Decoded: river
# Associates: ['river', 'water', 'brook', 'stream', 'noise', 'pond', 'lake', 'meadow', 'woods', 'turtle', 'squeak', 'fish', 'swim']
#
# Encoded word: hazard
# Decoded: risk
# Associates: ['danger', 'dangerous', 'light', 'caution', 'warning', 'risk', 'fire', 'waste', 'safe', 'bad', 'car', 'obstacle', 'sign', 'harmful', 'water']
#
# Encoded word: haircut
# Decoded: hair
# Associates: ['short', 'scissors', 'trim', 'hair', 'style', 'no', 'bad', 'shave', 'buzz', 'chop', 'long', 'messy', 'cheap', 'shampoo']
#
# Encoded word: division
# Decoded: unit
# Associates: ['math', 'separate', 'multiply', 'divide', 'addition', 'half', 'unit', 'group', 'split', 'section', 'department', 'bell', 'class', 'border', 'apart', 'subtraction']
#
# Encoded word: motor
# Decoded: engine
# Associates: ['car', 'engine', 'boat', 'motorcycle', 'run', 'vehicle', 'bike', 'oil', 'auto', 'mechanical', 'power', 'loud']
#
# Encoded word: much
# Decoded: lot
# Associates: ['lot', 'more', 'many', 'little', 'less', 'plenty', 'money']
#
# Encoded word: spring
# Decoded: summer
# Associates: ['summer', 'fall', 'water', 'flower', 'break', 'season', 'rain', 'bounce', 'winter', 'green', 'warm', 'cool', 'sun', 'board']
#
# Encoded word: slime
# Decoded: mud
# Associates: ['green', 'gross', 'goo', 'ghost', 'mold', 'scum', 'thin', 'skinny', 'slippery', 'dirt', 'turtle', 'mud']
#
# Encoded word: salmon
# Decoded: fish
# Associates: ['fish', 'pink', 'spawn', 'tuna', 'stream', 'upstream']
#
# Encoded word: supply
# Decoded: demand
# Associates: ['demand', 'give', 'food', 'air', 'amount', 'deny', 'empty', 'storage', 'stock']
#
# Encoded word: chemistry
# Decoded: biology
# Associates: ['science', 'biology', 'physics', 'chemical', 'lab', 'class', 'experiment', 'formula', 'test', 'hard', 'subject', 'element', 'math', 'test tube', 'equation']
#
# Encoded word: minute
# Decoded: hour
# Associates: ['second', 'hour', 'time', 'small', 'rice', 'watch', 'tiny']
#
# Encoded word: garbage
# Decoded: trash
# Associates: ['trash', 'can', 'bag', 'truck', 'smell', 'dirty', 'junk', 'pail', 'refuse', 'gross', 'out', 'man']
#
# Encoded word: handbag
# Decoded: backpack
# Associates: ['purse', 'pocketbook', 'bookbag', 'leather', 'book', 'backpack', 'wallet', 'lady', 'luggage', 'groceries', 'carry', 'girl', 'woman']
#
# Encoded word: downstream
# Decoded: river
# Associates: ['river', 'upstream', 'fish', 'water', 'flow', 'salmon', 'boat', 'canoe', 'float', 'easy', 'current', 'down', 'away']
#
# Encoded word: mansion
# Decoded: castle
# Associates: ['house', 'rich', 'big', 'home', 'money', 'wealth', 'huge', 'castle', 'shack', 'haunt', 'dracula']
#
# Encoded word: rat
# Decoded: snake
# Associates: ['mouse', 'rodent', 'cat', 'trap', 'animal', 'pest', 'ugly', 'tail', 'snake', 'cheese', 'dirty', 'disease', 'gray', 'teeth']
#
# Encoded word: labyrinth
# Decoded: maze
# Associates: ['maze', 'movie', 'puzzle', 'game', 'confusion', 'cave', 'magic', 'castle']
#
# Encoded word: keg
# Decoded: beer
# Associates: ['beer', 'barrel', 'party', 'container']
#
# Encoded word: bishop
# Decoded: priest
# Associates: ['church', 'pope', 'priest', 'chess', 'catholic', 'religion', 'cardinal', 'hat', 'knight', 'king', 'preacher', 'holy', 'saint', 'shop']
#
# Encoded word: north
# Decoded: south
# Associates: ['south', 'pole', 'up', 'cold', 'star', 'direction', 'east', 'new york']
#
# Encoded word: maroon
# Decoded: blue
# Associates: ['color', 'red', 'island', 'alone', 'purple', 'car', 'cookie', 'brown', 'dark', 'blue']
#
# Encoded word: steel
# Decoded: metal
# Associates: ['metal', 'iron', 'hard', 'strong', 'bar', 'plate', 'wool', 'silver', 'blade', 'car', 'machine', 'sword', 'building', 'pipe', 'cold', 'rod']
#
# Encoded word: snatch
# Decoded: grab
# Associates: ['take', 'grab', 'steal', 'purse', 'keep', 'rude', 'kidnap', 'hairy', 'catch']
#
# Encoded word: parcel
# Decoded: land
# Associates: ['package', 'post', 'mail', 'box', 'stamp', 'bag', 'piece', 'gift', 'postage', 'land', 'umbrella']
#
# Encoded word: inebriated
# Decoded: drunk
# Associates: ['drunk', 'drink', 'thought']
#
# Encoded word: summit
# Decoded: meeting
# Associates: ['peak', 'meeting', 'top', 'mountain', 'give', 'turn', 'conference', 'court', 'cliff', 'accept', 'horizon', 'paper', 'apex']
#
# Encoded word: property
# Decoded: land
# Associates: ['land', 'own', 'house', 'mine', 'tax', 'home', 'belong', 'value', 'damage', 'line', 'sell']
#
# Encoded word: devil
# Decoded: angel
# Associates: ['evil', 'angel', 'red', 'satan', 'god', 'hell', 'bad', 'demon', 'fire', 'horn']
#
# Encoded word: loft
# Decoded: apartment
# Associates: ['bed', 'hay', 'apartment', 'room', 'wood', 'attic', 'high', 'dorm', 'barn', 'stair', 'cabin', 'house', 'shelf', 'sleep']
#
# Encoded word: explosion
# Decoded: blast
# Associates: ['bomb', 'fire', 'boom', 'dynamite', 'bang', 'destroy', 'danger', 'volcano', 'blast', 'war', 'loud', 'nuclear', 'burst']
#
# Encoded word: polite
# Decoded: rude
# Associates: ['nice', 'rude', 'kind', 'manners', 'sweet', 'nasty', 'generous']
#
# Encoded word: brilliant
# Decoded: genius
# Associates: ['smart', 'bright', 'intelligent', 'genius', 'great', 'shine', 'color', 'superior', 'exceptional', 'dumb', 'stupid', 'sun']
#
# Encoded word: hive
# Decoded: bee
# Associates: ['bee', 'itch', 'nest', 'home', 'allergy']
#
# Encoded word: region
# Decoded: country
# Associates: ['area', 'land', 'place', 'north', 'section', 'country', 'part', 'south', 'usa', 'state']
#
# Encoded word: seashore
# Decoded: beach
# Associates: ['shell', 'beach', 'sand', 'ocean', 'water', 'sea', 'waves', 'sunset', 'surf', 'seagull', 'island', 'peace']
#
# Encoded word: clinic
# Decoded: hospital
# Associates: ['doctor', 'sick', 'hospital', 'health', 'nurse', 'medicine', 'medical', 'free', 'help', 'drug', 'office', 'aids']
#
# Encoded word: careful
# Decoded: cautious
# Associates: ['cautious', 'careless', 'safe', 'easy', 'delicate', 'fall', 'be', 'baby', 'sly', 'meticulous', 'dangerous', 'secure']
#
# Encoded word: brat
# Decoded: kid
# Associates: ['spoiled', 'kid', 'child', 'brother', 'sister', 'pain', 'jerk', 'mean', 'snot', 'obnoxious', 'annoying', 'baby', 'girl']
#
# Encoded word: unemployment
# Decoded: poverty
# Associates: ['job', 'poor', 'jobless', 'line', 'broke', 'work', 'money', 'welfare', 'homeless', 'poverty', 'employment', 'bum', 'me', 'office']
#
# Encoded word: fort
# Decoded: castle
# Associates: ['army', 'war', 'indian', 'protection', 'fight', 'building', 'strong', 'wall', 'camp', 'castle', 'wood', 'protect', 'cabin', 'gun', 'cave', 'tent', 'home', 'hut', 'woods']
#
# Encoded word: trousers
# Decoded: pants
# Associates: ['pants', 'slacks', 'belt', 'jeans', 'shirt']
#
# Encoded word: dryer
# Decoded: washer
# Associates: ['washer', 'hair', 'clothes', 'hot', 'laundry', 'heat', 'warm', 'sheets', 'clean']
#
# Encoded word: cavern
# Decoded: cave
# Associates: ['cave', 'dark', 'cabin', 'mountain', 'hole', 'bat', 'wood', 'cold', 'tunnel', 'tavern', 'mystery']
#
# Encoded word: presume
# Decoded: assume
# Associates: ['assume', 'innocent', 'guess', 'think', 'believe', 'guilt', 'suppose', 'dead']
#
# Encoded word: emergency
# Decoded: ambulance
# Associates: ['ambulance', 'hospital', 'help', 'accident', 'fast', 'quick', 'important', 'problem', 'urgent', 'fire', 'alarm', 'aid', 'immediate', 'medical', 'danger', 'exit', 'death', 'serious', 'call', 'now', 'hurry']
#
# Encoded word: poor
# Decoded: poverty
# Associates: ['rich', 'bad', 'people', 'old', 'money', 'dirty', 'poverty', 'house', 'lonely', 'welfare', 'sad']
#
# Encoded word: develop
# Decoded: build
# Associates: ['grow', 'make', 'mature', 'build', 'film', 'children', 'picture', 'learn', 'create', 'understand', 'form', 'start', 'body', 'begin']
#
# Encoded word: issue
# Decoded: debate
# Associates: ['magazine', 'topic', 'news', 'problem', 'debate', 'paper', 'give', 'fact', 'newspaper', 'subject', 'point', 'discuss', 'volume', 'politics', 'event', 'argument', 'idea', 'music', 'matter', 'book', 'world', 'tissue']
#
# Encoded word: voyage
# Decoded: sail
# Associates: ['trip', 'ship', 'journey', 'boat', 'travel', 'cruise', 'sea', 'sail', 'home', 'adventure']
#
# Encoded word: flavor
# Decoded: taste
# Associates: ['taste', 'ice cream', 'chocolate', 'strawberry', 'vanilla', 'cherry', 'sweet', 'spice', 'grape']
#
# Encoded word: shrine
# Decoded: statue
# Associates: ['temple', 'worship', 'church', 'religion', 'god', 'holy', 'pray', 'hospital', 'house', 'statue', 'synagogue', 'cemetery', 'king', 'monument', 'idol']
#
# Encoded word: widow
# Decoded: wife
# Associates: ['death', 'sad', 'woman', 'black', 'alone', 'lonely', 'old', 'single', 'wife', 'spider', 'spouse', 'husband']
#
# Encoded word: lipstick
# Decoded: mascara
# Associates: ['make up', 'red', 'lips', 'color', 'girl', 'mouth', 'woman', 'kiss', 'mascara', 'rouge']
#
# Encoded word: factory
# Decoded: plant
# Associates: ['worker', 'work', 'smoke', 'industry', 'plant', 'warehouse', 'machine', 'manufacturer', 'pollution', 'building', 'production', 'mill', 'shop', 'outlet', 'product', 'make', 'store', 'produce', 'labor', 'car', 'smog', 'business']
# Encoded word: acorn
# Decoded: squirrel
# Associates: ['tree', 'squirrel', 'nut', 'squash', 'seed', 'chipmunk']
#
# Encoded word: burglar
# Decoded: robber
# Associates: ['thief', 'robber', 'steal', 'alarm', 'rob', 'crook', 'cat', 'mask', 'robbery', 'bar', 'criminal', 'black', 'house', 'bad', 'cop', 'money', 'crime', 'movie']
#
# Encoded word: headache
# Decoded: pain
# Associates: ['pain', 'aspirin', 'migraine', 'tylenol', 'hurt', 'sinus', 'sick', 'pill', 'medicine', 'brain', 'fever']
#
# Encoded word: macaroni
# Decoded: pasta
# Associates: ['cheese', 'noodles', 'pasta', 'food', 'spaghetti', 'sauce', 'salad']
#
# Encoded word: ease
# Decoded: soothe
# Associates: ['easy', 'relax', 'hard', 'difficult', 'simple', 'slow', 'comfort', 'tense', 'pain', 'soothe', 'help', 'smooth', 'slide', 'ability', 'quick', 'nervous', 'grace', 'complex', 'mind', 'rest']
#
# Encoded word: chapter
# Decoded: book
# Associates: ['book', 'one', 'section', 'novel', 'verse', 'page', 'sorority']
#
# Encoded word: granite
# Decoded: stone
# Associates: ['rock', 'stone', 'hard', 'marble', 'lead', 'slab', 'mineral', 'sculpture']
#
# Encoded word: goose
# Decoded: geese
# Associates: ['gander', 'duck', 'egg', 'geese', 'bird', 'neck', 'mother', 'animal', 'hen', 'chicken', 'fly']
#
# Encoded word: victor
# Decoded: winner
# Associates: ['winner', 'win', 'name', 'loser', 'man', 'champion', 'victory', 'guy', 'success', 'war', 'lose']
#
# Encoded word: volcano
# Decoded: mountain
# Associates: ['erupt', 'lava', 'hot', 'fire', 'explode', 'ash', 'mountain', 'hawaii', 'island']
#
# Encoded word: sober
# Decoded: drunk
# Associates: ['drunk', 'awareness', 'clean', 'alcohol', 'straight', 'normal', 'driver']
#
# Encoded word: wrench
# Decoded: hammer
# Associates: ['tool', 'hammer', 'screwdriver', 'pull', 'pliers', 'socket', 'fix', 'monkey', 'work', 'turn', 'screw', 'plumber', 'mechanic', 'crescent', 'pipe', 'car', 'nut']
#
# Encoded word: purple
# Decoded: orange
# Associates: ['color', 'blue', 'pink', 'violet', 'orange', 'grape', 'red', 'green', 'deep', 'viking', 'heart', 'velvet', 'yellow']
#
# Encoded word: marry
# Decoded: wed
# Associates: ['divorce', 'love', 'wed', 'happy', 'husband', 'engage', 'single', 'wife', 'ring', 'wedding', 'man', 'unite', 'happiness', 'groom', 'commitment', 'church', 'join', 'never', 'hitch', 'union', 'family']
#
# Encoded word: villain
# Decoded: vampire
# Associates: ['bad', 'evil', 'hero', 'robber', 'criminal', 'mean', 'black', 'joker', 'movie', 'vampire']
#
# Encoded word: nervous
# Decoded: jumpy
# Associates: ['scared', 'tense', 'shake', 'anxious', 'sweat', 'stress', 'system', 'wreck', 'jumpy', 'habit', 'nails', 'test', 'tap', 'today', 'energy', 'class', 'worry', 'calm']
#
# Encoded word: disguise
# Decoded: hide
# Associates: ['mask', 'hide', 'halloween', 'fake', 'costume', 'cover', 'make up', 'hidden', 'mustache', 'secret', 'trick', 'fun', 'scary', 'sneaky']
#
# Encoded word: whom
# Decoded: who
# Associates: ['who', 'person', 'concern', 'you', 'what', 'proper', 'letter']
#
# Encoded word: awake
# Decoded: asleep
# Associates: ['asleep', 'alert', 'up', 'tired', 'alive', 'aware', 'morning', 'sleepy', 'alarm']
#
# Encoded word: stallion
# Decoded: mare
# Associates: ['horse', 'black', 'stud', 'italian', 'mare', 'store', 'wild']
#
# Encoded word: cathedral
# Decoded: church
# Associates: ['church', 'catholic', 'ceiling', 'steeple', 'religion', 'god', 'glass', 'building', 'roman']
#
# Encoded word: athletic
# Decoded: athlete
# Associates: ['sports', 'shoes', 'jock', 'muscle', 'football', 'strong', 'healthy', 'baseball', 'sweat', 'athlete', 'fit', 'person', 'field', 'shape', 'department', 'running', 'basketball', 'me', 'track']
#
# Encoded word: clarinet
# Decoded: flute
# Associates: ['flute', 'music', 'instrument', 'trumpet', 'horn', 'band', 'oboe', 'blow', 'play']
#
# Encoded word: calculate
# Decoded: determine
# Associates: ['math', 'figure', 'add', 'compute', 'calculator', 'computer', 'determine', 'think', 'number', 'subtract', 'punch', 'solve', 'record', 'work']
#
# Encoded word: porpoise
# Decoded: whale
# Associates: ['dolphin', 'animal', 'turtle', 'fish', 'sea', 'water', 'seal', 'tortoise', 'whale', 'slow', 'flipper']
#
# Encoded word: medieval
# Decoded: castle
# Associates: ['knight', 'times', 'old', 'ancient', 'castle', 'king', 'armor', 'history', 'period']
#
# Encoded word: descent
# Decoded: climb
# Associates: ['down', 'fall', 'ascent', 'lower', 'below', 'against', 'moral', 'ancestor', 'hell', 'decline', 'stair', 'climb', 'man']
#
# Encoded word: catholic
# Decoded: priest
# Associates: ['religion', 'church', 'jewish', 'priest', 'protestant', 'christian', 'religious', 'nun', 'pope', 'cross', 'school', 'roman', 'baptist', 'holy']
#
# Encoded word: symphony
# Decoded: orchestra
# Associates: ['orchestra', 'music', 'violin', 'band', 'concert', 'boring', 'instrument']
#
# Encoded word: prince
# Decoded: princess
# Associates: ['princess', 'king', 'queen', 'rich', 'frog', 'royalty', 'crown', 'music', 'handsome', 'castle']
#
# Encoded word: suds
# Decoded: beer
# Associates: ['soap', 'bubble', 'beer', 'bath', 'foam']
#
# Encoded word: amateur
# Decoded: professional
# Associates: ['professional', 'beginner', 'new', 'novice', 'expert', 'boxer', 'young', 'baseball', 'comedian', 'night', 'athlete']
#
# Encoded word: toad
# Decoded: frog
# Associates: ['frog', 'wart', 'slimy']
#
# Encoded word: compassion
# Decoded: caring
# Associates: ['love', 'sympathy', 'kind', 'heart', 'feeling', 'caring', 'empathy', 'passion', 'understanding', 'sincerity', 'women', 'nice', 'friend', 'sorrow', 'emotion', 'sweet', 'happy']
#
# Encoded word: jet
# Decoded: plane
# Associates: ['plane', 'fly', 'ski', 'fighter', 'fast', 'dry', 'set']
#
# Encoded word: triumph
# Decoded: defeat
# Associates: ['win', 'victory', 'car', 'succeed', 'defeat', 'overcome', 'beat', 'glory', 'fail', 'conquer', 'trumpet']
#
# Encoded word: obnoxious
# Decoded: annoying
# Associates: ['rude', 'loud', 'annoying', 'jerk', 'snotty', 'irritating', 'crazy', 'stupid', 'pain', 'me', 'snob', 'drunk', 'mean', 'bother', 'attitude', 'people', 'arrogant', 'silly', 'nose']
#
# Encoded word: cheerful
# Decoded: smile
# Associates: ['happy', 'joyous', 'sad', 'smile', 'cheerleader', 'laugh', 'gloomy']
#
# Encoded word: parrot
# Decoded: bird
# Associates: ['bird', 'talk', 'green', 'cracker', 'mimic', 'color', 'ape', 'pirate']
#
# Encoded word: scissors
# Decoded: knife
# Associates: ['cut', 'knife', 'sharp', 'paper']
#
# Encoded word: pitchfork
# Decoded: shovel
# Associates: ['hay', 'devil', 'farm', 'farmer', 'hoe', 'satan', 'haystack', 'shovel', 'fork', 'stab', 'horror', 'tool', 'garden', 'kill']
#
# Encoded word: daughter
# Decoded: mother
# Associates: ['son', 'mother', 'sister', 'father', 'girl', 'child', 'mom', 'brother', 'loving', 'baby', 'family', 'female', 'wife']
#
# Encoded word: nation
# Decoded: country
# Associates: ['country', 'usa', 'america', 'people', 'state', 'united', 'one', 'china', 'flag', 'continent', 'world']
#
# Encoded word: cyclone
# Decoded: twister
# Associates: ['tornado', 'hurricane', 'wind', 'storm', 'disaster', 'destruction', 'twister', 'weather', 'eye', 'giant']
#
# Encoded word: candidate
# Decoded: politician
# Associates: ['president', 'election', 'politics', 'politician', 'elect', 'run', 'person', 'winner', 'vote', 'jerk', 'campaign', 'republican']
#
# Encoded word: wet
# Decoded: rain
# Associates: ['dry', 'cold', 'water', 'rain', 'swim', 'damp', 'soak', 'paint', 'slippery', 'pool']
#
# Encoded word: ass
# Decoded: butt
# Associates: ['donkey', 'hole', 'butt', 'jack', 'jerk', 'horse', 'kiss', 'mule', 'stupid', 'round', 'men', 'cute', 'fine']
#
# Encoded word: underground
# Decoded: tunnel
# Associates: ['railroad', 'tunnel', 'below', 'subway', 'dirt', 'beneath', 'basement', 'dark', 'music', 'train', 'bottom', 'cavern']
#
# Encoded word: weary
# Decoded: tired
# Associates: ['tired', 'unsure', 'scared', 'eyes', 'sleepy', 'weak', 'old', 'work', 'energetic', 'dream']
#
# Encoded word: trial
# Decoded: jury
# Associates: ['court', 'jury', 'lawyer', 'case', 'judge', 'error', 'law', 'test', 'sentence', 'guilt', 'path', 'judgment', 'criminal']
#
# Encoded word: evil
# Decoded: sin
# Associates: ['good', 'devil', 'bad', 'wicked', 'eye', 'satan', 'mean', 'witch', 'sin', 'nice', 'cruel']
#
# Encoded word: fiction
# Decoded: book
# Associates: ['book', 'story', 'false', 'fake', 'science', 'untrue', 'truth', 'fact', 'real', 'novel', 'fantasy', 'space', 'reality']
#
# Encoded word: mason
# Decoded: carpenter
# Associates: ['brick', 'jar', 'worker', 'house', 'concrete', 'cement', 'lawyer', 'carpenter', 'builder', 'block', 'build', 'skill', 'television', 'murder', 'name', 'contractor']
#
# Encoded word: sergeant
# Decoded: officer
# Associates: ['army', 'military', 'lieutenant', 'general', 'police', 'doctor', 'major', 'drill', 'officer', 'cop', 'rank', 'authority', 'navy', 'air force', 'arms']
#
# Encoded word: bass
# Decoded: guitar
# Associates: ['fish', 'guitar', 'treble', 'drum', 'music', 'violin', 'instrument', 'shoes', 'cello', 'lake', 'sound', 'radio', 'boom']
#
# Encoded word: jail
# Decoded: prison
# Associates: ['prison', 'bar', 'house', 'cell', 'criminal', 'lock', 'bad', 'convict', 'bait', 'crime', 'prisoner', 'bird', 'thief', 'police']
#
# Encoded word: southern
# Decoded: south
# Associates: ['florida', 'country', 'food', 'chicken', 'cooking', 'comfort', 'baptist', 'south', 'warm']
#
# Encoded word: six
# Decoded: five
# Associates: ['seven', 'number', 'nine', 'sex', 'five', 'three', 'feet']
#
# Encoded word: reappear
# Decoded: appear
# Associates: ['disappear', 'magic', 'again', 'show', 'appear', 'see', 'ghost', 'return', 'fix', 'repeat', 'vanish', 'missing']
#
# Encoded word: cozy
# Decoded: snuggle
# Associates: ['comfortable', 'warm', 'couch', 'bed', 'snuggle', 'safe', 'cuddle', 'fireplace', 'fire', 'soft', 'quiet', 'nice']
# Encoded word: danger
# Decoded: risk
# Associates: ['scary', 'fear', 'fire', 'trouble', 'warning', 'death', 'safe', 'caution', 'sign', 'zone', 'fun', 'red', 'risk', 'accident', 'bad', 'adventure', 'hurt', 'curve', 'alert', 'exciting', 'careful', 'evil']
#
# Encoded word: arctic
# Decoded: snow
# Associates: ['cold', 'ocean', 'ice', 'circle', 'snow', 'north', 'bear', 'frigid']
#
# Encoded word: verdict
# Decoded: jury
# Associates: ['guilty', 'decision', 'judge', 'court', 'jury', 'judgment', 'sentence', 'answer', 'law', 'conclusion', 'truth', 'trial', 'end', 'final', 'result', 'outcome']
#
# Encoded word: upstream
# Decoded: river
# Associates: ['downstream', 'river', 'salmon', 'fish', 'water', 'swim', 'down', 'paddle', 'trout', 'current', 'hard', 'boat', 'high', 'fight']
#
# Encoded word: ruler
# Decoded: king
# Associates: ['measure', 'king', 'inch', 'pencil', 'dictator', 'straight', 'stick', 'wood', 'number', 'math', 'tool', 'pen', 'edge', 'line', 'geometry', 'meter']
#
# Encoded word: east
# Decoded: south
# Associates: ['west', 'coast', 'south', 'slow']
#
# Encoded word: physician
# Decoded: doctor
# Associates: ['doctor', 'heal', 'needle', 'smart']
#
# Encoded word: chart
# Decoded: diagram
# Associates: ['graph', 'map', 'table', 'doctor', 'diagram', 'numbers', 'hospital', 'paper', 'medical', 'point', 'statistics', 'eye', 'data', 'write', 'math', 'pie', 'sea']
#
# Encoded word: media
# Decoded: news
# Associates: ['television', 'news', 'newspaper', 'camera', 'library', 'press', 'center', 'society', 'play', 'paper', 'public', 'bias', 'radio']
#
# Encoded word: scalp
# Decoded: skin
# Associates: ['hair', 'head', 'dandruff', 'indian', 'bald', 'itch', 'cut', 'skin', 'dry']
#
# Encoded word: chauffeur
# Decoded: limousine
# Associates: ['driver', 'car', 'limousine', 'drive']
#
# Encoded word: dawn
# Decoded: sunrise
# Associates: ['dusk', 'morning', 'sun', 'sunrise', 'day', 'early', 'sunset', 'dark', 'night', 'sunshine']
#
# Encoded word: foggy
# Decoded: cloudy
# Associates: ['unclear', 'cloudy', 'smoky', 'see', 'smog', 'night', 'rainy', 'day', 'weather', 'dense', 'morning', 'scary', 'england', 'white', 'dark', 'tired']
#
# Encoded word: diaper
# Decoded: baby
# Associates: ['baby', 'rash', 'dirty', 'stink', 'child', 'cloth', 'paper']
#
# Encoded word: bone
# Decoded: skull
# Associates: ['dog', 'break', 'marrow', 'skeleton', 'leg', 'steak', 'china', 'chicken', 'skin', 'body', 'skull', 'head', 'arm', 'muscle', 'hard', 'tissue', 'white']
#
# Encoded word: doorway
# Decoded: hallway
# Associates: ['door', 'entrance', 'hallway', 'open', 'opening', 'enter', 'threshold', 'knob', 'jam', 'passage', 'exit', 'room', 'walkway', 'house', 'inside', 'frame', 'outside']
#
# Encoded word: brook
# Decoded: river
# Associates: ['stream', 'river', 'water', 'creek', 'pond']
#
# Encoded word: spaghetti
# Decoded: pasta
# Associates: ['sauce', 'meatballs', 'noodles', 'food', 'pasta', 'italian', 'yummy', 'tomato', 'dinner', 'eat']
#
# Encoded word: wheat
# Decoded: corn
# Associates: ['bread', 'barley', 'germ', 'field', 'cereal', 'oats', 'hay', 'food', 'grain', 'corn', 'flower', 'whole', 'rye', 'buck', 'toast']
#
# Encoded word: sentence
# Decoded: prison
# Associates: ['words', 'paragraph', 'period', 'structure', 'prison', 'english', 'jail', 'compose', 'judge', 'talk', 'phrase', 'death', 'noun', 'question', 'spell', 'time']
#
# Encoded word: brandy
# Decoded: wine
# Associates: ['liquor', 'alcohol', 'drink', 'wine', 'rum', 'whiskey', 'gin', 'drunk', 'glass']
#
# Encoded word: pike
# Decoded: fish
# Associates: ['fraternity', 'peak', 'fish', 'turn', 'highway', 'spike', 'top', 'drive', 'house', 'mountain']
#
# Encoded word: sliver
# Decoded: slice
# Associates: ['gold', 'movie', 'cut', 'snake', 'piece', 'wood', 'pain', 'metal', 'slice', 'splinter', 'glass', 'finger', 'hurt', 'ouch', 'silver', 'slime', 'jewelry']
#
# Encoded word: alcohol
# Decoded: drink
# Associates: ['beer', 'drink', 'drug', 'drunk', 'abuse', 'fun', 'party', 'intoxicate', 'problem', 'vodka']
#
# Encoded word: freedom
# Decoded: speech
# Associates: ['usa', 'liberty', 'fighter', 'peace', 'forever', 'flag', 'democracy', 'new', 'justice', 'rock', 'good', 'great', 'yes', 'speech', 'happiness', 'country', 'bell', 'independent', 'free', 'bondage']
#
# Encoded word: democrat
# Decoded: politician
# Associates: ['republican', 'politics', 'president', 'politician', 'liberal', 'republic', 'fair', 'me', 'donkey']
#
# Encoded word: brand
# Decoded: product
# Associates: ['name', 'type', 'new', 'label', 'kind', 'cereal', 'cow', 'style', 'expensive', 'store', 'product', 'clothes']
#
# Encoded word: tide
# Decoded: wave
# Associates: ['water', 'ocean', 'wave', 'detergent', 'high', 'beach', 'soap', 'laundry', 'sea', 'surf', 'clean', 'moon', 'red', 'clothes', 'shore']
#
# Encoded word: soot
# Decoded: dust
# Associates: ['dirt', 'chimney', 'black', 'ash', 'dirty', 'fireplace', 'boot', 'fire', 'soil', 'roof', 'coal', 'mud', 'dust', 'ashes']
#
# Encoded word: toilet
# Decoded: tub
# Associates: ['bathroom', 'seat', 'flush', 'paper', 'bowl', 'tub', 'sink', 'sit', 'dirty', 'water', 'restroom']
#
# Encoded word: brass
# Decoded: horn
# Associates: ['gold', 'shine', 'metal', 'copper', 'bed', 'instrument', 'trumpet', 'knuckle', 'horn', 'silver', 'band', 'tarnish', 'monkey', 'ring', 'lamp', 'polish', 'music', 'plate', 'bell']
#
# Encoded word: canal
# Decoded: river
# Associates: ['water', 'river', 'boat', 'root', 'lake', 'zone', 'stream', 'ditch', 'birth', 'tooth', 'street', 'house', 'creek', 'dirty', 'dog']
#
# Encoded word: principal
# Decoded: teacher
# Associates: ['school', 'teacher', 'leader', 'authority', 'head', 'important', 'idea', 'pleasure', 'theorem', 'moral', 'main', 'first', 'office', 'master', 'boss', 'thought']
#
# Encoded word: idol
# Decoded: statue
# Associates: ['hero', 'statue', 'god', 'star', 'worship', 'admire', 'famous', 'person', 'me', 'speed', 'car']
#
# Encoded word: wary
# Decoded: cautious
# Associates: ['tired', 'cautious', 'unsure', 'scared', 'weak', 'careful', 'weary', 'worry', 'sick', 'shy', 'nervous', 'strong', 'fear', 'uneasy']
#
# Encoded word: coat
# Decoded: jacket
# Associates: ['jacket', 'hat', 'cold', 'warm', 'winter', 'rain', 'fur', 'sweater', 'tie', 'cover', 'clothes', 'mink', 'heavy', 'paint', 'over', 'hang']
#
# Encoded word: colt
# Decoded: mare
# Associates: ['horse', 'pony', 'baby', 'mare', 'gun', 'young']
#
# Encoded word: honeymoon
# Decoded: wedding
# Associates: ['wedding', 'marriage', 'sex', 'love', 'suite', 'romance', 'vacation', 'couple', 'island', 'lovers', 'happy', 'fun', 'divorce', 'sweetheart']
#
# Encoded word: tulip
# Decoded: flower
# Associates: ['flower', 'rose', 'pretty', 'bulb', 'red', 'plant']
#
# Encoded word: intoxicated
# Decoded: drunk
# Associates: ['drunk', 'alcohol', 'beer', 'drugs', 'inebriated']
#
# Encoded word: buddy
# Decoded: friend
# Associates: ['friend', 'pal', 'system']
#
# Encoded word: slim
# Decoded: trim
# Associates: ['fat', 'skinny', 'thin', 'trim', 'tall', 'slender', 'nice']
#
# Encoded word: crazy
# Decoded: mad
# Associates: ['insane', 'weird', 'wild', 'mad', 'nuts', 'fun', 'strange', 'normal', 'silly', 'sick']
#
# Encoded word: crook
# Decoded: robber
# Associates: ['thief', 'robber', 'criminal', 'burglar', 'bad', 'dishonest', 'jail', 'steal', 'book', 'mask']
#
# Encoded word: famished
# Decoded: starving
# Associates: ['hungry', 'starving', 'food', 'fame', 'gone', 'people', 'tired']
#
# Encoded word: soft
# Decoded: smooth
# Associates: ['hard', 'cuddle', 'baby', 'smooth', 'gentle', 'nice', 'feather', 'pillow', 'cotton', 'warm', 'skin', 'comfortable', 'silk', 'breast', 'light', 'pretty', 'hair', 'touch']
#
# Encoded word: critic
# Decoded: writer
# Associates: ['movie', 'analyze', 'criticize', 'opinion', 'newspaper', 'news', 'mean', 'art', 'writer', 'insult', 'bad', 'review', 'judge', 'cartoon', 'people']
#
# Encoded word: dope
# Decoded: weed
# Associates: ['drugs', 'pot', 'marijuana', 'idiot', 'stupid', 'smoke', 'weed', 'dumb', 'crack', 'smart', 'addict', 'dwarf', 'high']
#
# Encoded word: lagoon
# Decoded: lake
# Associates: ['water', 'blue', 'lake', 'swamp', 'pond', 'island', 'inlet', 'monster', 'black', 'swim', 'love', 'creature']
#
# Encoded word: careless
# Decoded: reckless
# Associates: ['reckless', 'driver', 'careful', 'sloppy', 'clumsy', 'mistake', 'messy', 'free', 'car', 'foolish', 'stupid']
#
# Encoded word: daily
# Decoded: everyday
# Associates: ['news', 'weekly', 'routine', 'newspaper', 'everyday', 'always', 'paper', 'today', 'monthly', 'day', 'bread', 'regular', 'often', 'log', 'ritual', 'schedule']
#
# Encoded word: patriotic
# Decoded: salute
# Associates: ['flag', 'loyal', 'american', 'country', 'hero', 'usa', 'nation', 'soldier', 'proud', 'person', 'man', 'pride', 'citizen', 'duty', 'honor', 'freedom', 'symbol', 'america', 'salute', 'army']
#
# Encoded word: holler
# Decoded: yell
# Associates: ['yell', 'scream', 'shout', 'loud']
#
# Encoded word: theft
# Decoded: stolen
# Associates: ['steal', 'burglar', 'crime', 'robbery', 'stolen', 'thief', 'criminal', 'robber', 'car', 'burglary', 'bad', 'wrong', 'rob', 'crook', 'kill']
#
# Encoded word: desert
# Decoded: cactus
# Associates: ['sand', 'dry', 'hot', 'cactus', 'oasis', 'leave', 'island']
#
# Encoded word: sandals
# Decoded: shoes
# Associates: ['shoes', 'feet', 'beach', 'summer', 'toes', 'comfort', 'sand', 'leather', 'hot', 'vacation']
#
# Encoded word: breezeway
# Decoded: hallway
# Associates: ['walkway', 'wind', 'hallway', 'hall', 'air', 'cold', 'walk', 'ocean', 'cool', 'open', 'beach', 'porch', 'easy', 'house', 'sidewalk', 'bridge', 'tunnel']
#
# Encoded word: eyelash
# Decoded: mascara
# Associates: ['eye', 'mascara', 'long', 'eyes', 'protection', 'wish', 'hair', 'face', 'make up']
#
# Encoded word: oboe
# Decoded: flute
# Associates: ['instrument', 'flute', 'music', 'clarinet', 'horn', 'woodwind', 'what', 'saxophone', 'cello', 'band', 'orchestra', 'violin', 'trumpet']
#
# Encoded word: otter
# Decoded: mammal
# Associates: ['animal', 'seal', 'beaver', 'water', 'sea', 'cute', 'river', 'lake', 'stream', 'slick', 'mammal', 'ocean', 'wood']
#
# Encoded word: supper
# Decoded: dinner
# Associates: ['dinner', 'food', 'time', 'hungry', 'lunch', 'eat', 'chicken', 'meal', 'breakfast', 'great', 'last']
#
# Encoded word: bath
# Decoded: tub
# Associates: ['shower', 'clean', 'water', 'tub', 'bubble', 'room', 'soap', 'wash', 'towel', 'house']
#
# Encoded word: elk
# Decoded: deer
# Associates: ['deer', 'moose', 'animal', 'club', 'tree', 'antler', 'horn', 'hunt', 'doe']
# Encoded word: comprehend
# Decoded: understand
# Associates: ['understand', 'learn', 'read', 'know']
#
# Encoded word: employer
# Decoded: employee
# Associates: ['boss', 'employee', 'work', 'job', 'worker', 'money', 'check']
#
# Encoded word: paddy
# Decoded: rice
# Associates: ['wagon', 'cake', 'hamburger', 'rice', 'soft', 'cushion', 'cow', 'meat', 'boat', 'pad', 'comfortable', 'bear', 'person']
#
# Encoded word: organization
# Decoded: group
# Associates: ['group', 'club', 'neat', 'together', 'messy', 'tidy', 'order', 'people', 'mafia', 'business', 'chaos', 'skill', 'gang', 'mob', 'team', 'sorority', 'company']
#
# Encoded word: slogan
# Decoded: banner
# Associates: ['ad', 'saying', 'word', 'campaign', 'commercial', 'banner', 'sign', 'product', 'phrase', 'theme', 'coke', 'candidate', 'sell']
#
# Encoded word: robin
# Decoded: bird
# Associates: ['bird', 'hood', 'red', 'eggs', 'nest']
#
# Encoded word: alarm
# Decoded: alert
# Associates: ['clock', 'bell', 'awake', 'sound', 'scare', 'ring', 'fire', 'morning', 'alert', 'fright', 'up', 'loud']
#
# Encoded word: grove
# Decoded: tree
# Associates: ['orange', 'tree', 'orchard', 'apple', 'field', 'ditch', 'park', 'bush', 'group', 'peach']
#
# Encoded word: humid
# Decoded: rain
# Associates: ['hot', 'wet', 'florida', 'weather', 'foggy', 'sticky', 'dry', 'sweat', 'moist', 'rain', 'temperature', 'hair', 'damp', 'air']
#
# Encoded word: physics
# Decoded: biology
# Associates: ['science', 'math', 'hard', 'chemistry', 'motion', 'class', 'difficult', 'crazy', 'law', 'biology', 'school']
#
# Encoded word: kidnap
# Decoded: abduct
# Associates: ['take', 'child', 'steal', 'abduct', 'kids', 'scary', 'torture', 'money', 'bad', 'horrible', 'baby']
#
# Encoded word: predator
# Decoded: shark
# Associates: ['prey', 'animal', 'lion', 'movie', 'monster', 'enemy', 'eat', 'shark', 'victim', 'killer', 'cat', 'dinosaur', 'attack', 'dangerous', 'tiger']
#
# Encoded word: oatmeal
# Decoded: cereal
# Associates: ['cereal', 'breakfast', 'cookie', 'food', 'hot', 'morning', 'good', 'gross', 'yuck', 'slimy', 'bran', 'health', 'apple', 'disgust']
#
# Encoded word: monarch
# Decoded: king
# Associates: ['king', 'ruler', 'butterfly', 'queen', 'government', 'leader', 'rule', 'car', 'dictator']
#
# Encoded word: horizon
# Decoded: sky
# Associates: ['sun', 'sunset', 'sky', 'beauty', 'event', 'end', 'landscape', 'ocean', 'line', 'view', 'blue']
#
# Encoded word: visitor
# Decoded: tourist
# Associates: ['guest', 'friend', 'relative', 'hospital', 'stranger', 'patient', 'company', 'home', 'tourist', 'pass', 'welcome', 'new']
#
# Encoded word: victory
# Decoded: win
# Associates: ['win', 'defeat', 'winner', 'champion', 'lose', 'soccer', 'war', 'battle', 'football', 'conquest', 'triumph', 'great']
#
# Encoded word: choice
# Decoded: choose
# Associates: ['decision', 'pick', 'freedom', 'choose', 'selection', 'opinion', 'option', 'alternative', 'meat', 'first', 'opportunity', 'none', 'make', 'variety']
#
# Encoded word: palace
# Decoded: castle
# Associates: ['castle', 'king', 'kingdom', 'queen', 'mansion', 'home', 'house', 'guard', 'royalty', 'beautiful', 'prince', 'royal', 'dance', 'large']
#
# Encoded word: red
# Decoded: yellow
# Associates: ['blue', 'white', 'rose', 'color', 'cross', 'blood', 'black', 'green', 'yellow', 'dress', 'bright', 'orange', 'hair']
#
# Encoded word: liquor
# Decoded: beer
# Associates: ['beer', 'drunk', 'alcohol', 'drink', 'vodka', 'booze', 'wine', 'rum', 'gin', 'hard', 'store', 'intoxicate', 'bad', 'party', 'sweet', 'strong', 'scotch']
#
# Encoded word: irritating
# Decoded: annoying
# Associates: ['annoying', 'rash', 'mad', 'eyes', 'noise', 'people', 'roommate', 'brother', 'hurt', 'anger']
#
# Encoded word: porcelain
# Decoded: vase
# Associates: ['doll', 'china', 'vase', 'fragile', 'white', 'break', 'delicate', 'glass', 'expensive', 'god', 'ceramic', 'plate', 'tile', 'sink', 'bowl', 'dish']
#
# Encoded word: buyer
# Decoded: seller
# Associates: ['seller', 'customer', 'purchase', 'car', 'money', 'house']
#
# Encoded word: timber
# Decoded: lumber
# Associates: ['wood', 'tree', 'lumber', 'forest', 'fall', 'bark', 'log', 'lake']
#
# Encoded word: chance
# Decoded: hope
# Associates: ['luck', 'opportunity', 'risk', 'try', 'take', 'gamble', 'happen', 'lottery', 'last', 'hope', 'fate', 'one', 'time', 'possible', 'probability', 'option', 'maybe', 'guess', 'good']
#
# Encoded word: harp
# Decoded: flute
# Associates: ['music', 'instrument', 'string', 'angel', 'violin', 'piano', 'heaven', 'nag', 'beautiful', 'play', 'flute', 'cord', 'pitch', 'song', 'soft', 'sing']
#
# Encoded word: pastry
# Decoded: dough
# Associates: ['doughnut', 'sweet', 'cake', 'dessert', 'pie', 'food', 'chef', 'fat', 'good', 'french', 'eat', 'dough', 'yummy', 'bagel', 'apple', 'bread', 'calories']
#
# Encoded word: twine
# Decoded: rope
# Associates: ['string', 'rope', 'together', 'twist', 'yarn', 'wire', 'mix', 'between', 'roll', 'vine', 'line', 'bond', 'wrap', 'thread']
#
# Encoded word: dorm
# Decoded: apartment
# Associates: ['room', 'home', 'house', 'live', 'apartment', 'sleep', 'school', 'small', 'fun', 'college', 'party', 'noise', 'hall', 'roach', 'life']
#
# Encoded word: evidence
# Decoded: proof
# Associates: ['proof', 'crime', 'guilty', 'court', 'trial', 'clue', 'police', 'case', 'blood', 'prove', 'fact', 'witness', 'cop', 'material', 'law']
#
# Encoded word: response
# Decoded: respond
# Associates: ['answer', 'question', 'action', 'reaction', 'talk', 'quick', 'negative', 'respond', 'first', 'reply', 'time', 'speak']
#
# Encoded word: ten
# Decoded: five
# Associates: ['number', 'nine', 'dollars', 'fingers', 'perfect', 'five', 'four', 'zero', 'dice', 'pin', 'minutes', 'dime', 'cents', 'money', 'one', 'hundred']
#
# Encoded word: vulgar
# Decoded: rude
# Associates: ['rude', 'language', 'nasty', 'gross', 'bad', 'mean', 'sick', 'disgusting', 'crude', 'dirty', 'ugly', 'mouth', 'foul']
#
# Encoded word: central
# Decoded: main
# Associates: ['middle', 'location', 'park', 'station', 'center', 'time', 'city', 'america', 'main', 'division', 'tendency', 'north', 'florida', 'high']
#
# Encoded word: melody
# Decoded: song
# Associates: ['song', 'music', 'tune', 'harmony', 'rhythm']
#
# Encoded word: suburb
# Decoded: neighborhood
# Associates: ['city', 'house', 'town', 'rural', 'neighborhood', 'home', 'country', 'great', 'rich', 'ghetto', 'boring']
#
# Encoded word: local
# Decoded: community
# Associates: ['near', 'close', 'city', 'here', 'far', 'national', 'home', 'government', 'distance', 'area', 'neighbor', 'phone', 'store', 'community', 'state', 'police', 'native', 'country', 'news', 'town', 'mall', 'foreign', 'place']
#
# Encoded word: throne
# Decoded: king
# Associates: ['king', 'chair', 'queen', 'crown', 'castle', 'toilet', 'seat']
#
# Encoded word: monster
# Decoded: dragon
# Associates: ['scare', 'frankenstein', 'ugly', 'fear', 'big', 'movie', 'creature', 'dracula', 'animal', 'mash', 'horror', 'ghost', 'horrible', 'giant', 'evil', 'halloween', 'green', 'dragon', 'scream']
#
# Encoded word: emerald
# Decoded: diamond
# Associates: ['green', 'diamond', 'gem', 'ruby', 'stone', 'ring', 'blue', 'sapphire']
#
# Encoded word: waffles
# Decoded: pancakes
# Associates: ['syrup', 'pancakes', 'breakfast', 'food', 'eggs', 'house', 'good', 'toaster', 'bacon']
#
# Encoded word: canvas
# Decoded: painting
# Associates: ['tent', 'shoes', 'paint', 'painting', 'art', 'bag', 'cover', 'material', 'painter', 'oil', 'picture', 'boat', 'green', 'bookbag', 'clothes']
#
# Encoded word: curtains
# Decoded: drapes
# Associates: ['drapes', 'window', 'blinds', 'rod', 'shade', 'open', 'close', 'house', 'shower', 'cover', 'hang', 'fabric', 'stage', 'closed', 'room']
#
# Encoded word: vine
# Decoded: grape
# Associates: ['grape', 'wine', 'plant', 'ivy', 'jungle', 'yard', 'tarzan', 'climb', 'leaf', 'rope', 'branch', 'green']
#
# Encoded word: eyeball
# Decoded: eye
# Associates: ['socket', 'eye', 'face', 'see', 'eyelash', 'glasses', 'nose', 'eyes', 'vision', 'sight', 'look', 'contacts', 'pupil', 'head', 'watch', 'round']
#
# Encoded word: ax
# Decoded: knife
# Associates: ['tree', 'handle', 'chop', 'wood', 'sharp', 'murder', 'knife', 'hammer', 'cut', 'kill', 'hatchet', 'tool', 'pick', 'blood', 'saw', 'head', 'sword', 'what']
#
# Encoded word: knee
# Decoded: ankle
# Associates: ['leg', 'bend', 'joint', 'jerk', 'ankle', 'elbow', 'cap', 'foot', 'calf', 'bone', 'arm', 'socks']
#
# Encoded word: fossil
# Decoded: dinosaur
# Associates: ['dinosaur', 'fuel', 'bone', 'old', 'rock', 'ancient', 'shell', 'stone', 'remain', 'watch', 'dig']
#
# Encoded word: briefcase
# Decoded: backpack
# Associates: ['business', 'suitcase', 'lawyer', 'work', 'leather', 'suit', 'paper', 'bag', 'document', 'executive', 'wallet', 'folder', 'important', 'note', 'backpack', 'office']
#
# Encoded word: scalpel
# Decoded: knife
# Associates: ['doctor', 'knife', 'cut', 'surgery', 'surgeon', 'sharp', 'instrument', 'tool', 'operation', 'metal', 'scissors']
# Encoded word: slippers
# Decoded: shoes
# Associates: ['shoes', 'feet', 'robe', 'bedroom', 'fuzzy', 'furry', 'socks', 'bed']
#
# Encoded word: cousin
# Decoded: brother
# Associates: ['relative', 'aunt', 'family', 'uncle', 'friend', 'nephew', 'brother', 'kin', 'kid']
#
# Encoded word: autumn
# Decoded: summer
# Associates: ['fall', 'leaves', 'spring', 'season', 'summer', 'brown', 'color', 'rain', 'tree']
#
# Encoded word: butler
# Decoded: maid
# Associates: ['maid', 'servant', 'rich', 'waiter', 'wealth', 'meat', 'door', 'mansion', 'tuxedo', 'money', 'man']
#
# Encoded word: four
# Decoded: five
# Associates: ['five', 'number', 'three', 'golf', 'fire', 'square', 'score', 'eight', 'fingers', 'two']
#
# Encoded word: spice
# Decoded: seasoning
# Associates: ['sugar', 'salt', 'pepper', 'cinnamon', 'hot', 'food', 'flavor', 'taste', 'seasoning', 'nice', 'garlic', 'herb', 'oregano', 'smell', 'cake', 'sweet', 'rack']
#
# Encoded word: fox
# Decoded: wolf
# Associates: ['hound', 'animal', 'dog', 'sly', 'trot', 'red', 'hunt', 'wolf', 'hole', 'fur', 'rabbit', 'cunning', 'quick', 'cute', 'tail', 'coat', 'smart', 'ugly']
#
# Encoded word: comedy
# Decoded: comedian
# Associates: ['funny', 'laugh', 'humor', 'drama', 'club', 'tragedy', 'joke', 'fun', 'movie', 'comedian', 'routine']
#
# Encoded word: rays
# Decoded: sun
# Associates: ['sun', 'light', 'sting', 'sunshine', 'harmful']
#
# Encoded word: integrity
# Decoded: respect
# Associates: ['honesty', 'pride', 'honor', 'truth', 'moral', 'respect', 'money', 'power', 'trust', 'sincerity', 'value', 'strength', 'ambition', 'father', 'smart']
#
# Encoded word: vapor
# Decoded: fumes
# Associates: ['water', 'steam', 'gas', 'mist', 'smell', 'odor', 'breathe', 'air', 'rub', 'fumes', 'hot', 'chemistry', 'nose', 'pressure', 'disappear']
#
# Encoded word: perish
# Decoded: die
# Associates: ['die', 'disappear', 'gone', 'church', 'leave', 'spoil', 'destroy', 'fade', 'end', 'disintegrate', 'dead', 'treasure', 'rotten', 'finish', 'fire', 'exist', 'death', 'dissolve', 'live', 'vanish', 'burn', 'starve', 'wasted']
#
# Encoded word: lime
# Decoded: lemon
# Associates: ['lemon', 'green', 'sour', 'juice', 'stone', 'light', 'fruit', 'tart', 'rock']
#
# Encoded word: odor
# Decoded: smell
# Associates: ['smell', 'stink', 'feet', 'deodorant', 'skunk', 'stench']
#
# Encoded word: transplant
# Decoded: surgery
# Associates: ['heart', 'move', 'replace', 'hair', 'surgery', 'kidney', 'operation', 'remove', 'brain', 'exchange', 'organ', 'breast', 'liver', 'change', 'put']
#
# Encoded word: direction
# Decoded: path
# Associates: ['north', 'up', 'way', 'arrow', 'left', 'right', 'lost', 'south', 'stop', 'map', 'instruction', 'west', 'east', 'compass', 'where', 'point', 'straight', 'go', 'path', 'follow', 'order', 'wrong', 'forward', 'heading']
#
# Encoded word: hurricane
# Decoded: storm
# Associates: ['storm', 'wind', 'tornado', 'rain', 'destruction', 'water', 'disaster', 'florida', 'weather', 'typhoon', 'scary']
#
# Encoded word: world
# Decoded: country
# Associates: ['earth', 'globe', 'universe', 'round', 'wide', 'map', 'big', 'people', 'country', 'war', 'sphere', 'atlas']
#
# Encoded word: antelope
# Decoded: deer
# Associates: ['deer', 'animal', 'antler', 'horn', 'gazelle', 'beast', 'moose', 'fruit', 'buffalo']
#
# Encoded word: clippers
# Decoded: shears
# Associates: ['scissors', 'hair', 'nails', 'cut', 'haircut', 'hedge', 'grass', 'toenail', 'los angeles', 'shears', 'bush', 'paper', 'trim']
#
# Encoded word: robe
# Decoded: gown
# Associates: ['bath', 'gown', 'clothes', 'cover', 'slippers', 'pajamas', 'coat', 'shower', 'night', 'towel', 'dress', 'wear', 'warm', 'cloth', 'nightgown']
#
# Encoded word: dairy
# Decoded: milk
# Associates: ['milk', 'cow', 'secret', 'farm', 'private', 'cheese', 'product', 'journal', 'queen', 'ice cream', 'book', 'food']
#
# Encoded word: pushy
# Decoded: rude
# Associates: ['mean', 'rude', 'shove', 'aggressive', 'bully', 'annoying', 'force', 'arrogant', 'forward', 'touchy', 'jerk', 'mom', 'harsh', 'impatient', 'person', 'obnoxious']
#
# Encoded word: smoky
# Decoded: smoke
# Associates: ['bear', 'fire', 'cigarette', 'mountain', 'fog', 'bar', 'club', 'room', 'bandit', 'smoke', 'chimney', 'pollution', 'house', 'barbecue', 'clear']
#
# Encoded word: status
# Decoded: position
# Associates: ['position', 'rank', 'quotient', 'symbol', 'level', 'marriage', 'social', 'high', 'single', 'title', 'standing', 'wealth', 'prestige', 'place', 'class', 'money', 'information', 'worth', 'moral', 'situation', 'check']
#
# Encoded word: eager
# Decoded: anxious
# Associates: ['beaver', 'anxious', 'willing', 'excited', 'ready', 'ambition', 'want', 'lazy', 'hurry', 'learn', 'work', 'aggressive', 'impatient', 'happy', 'patient', 'positive']
#
# Encoded word: verse
# Decoded: song
# Associates: ['song', 'poem', 'bible', 'poetry', 'rhyme', 'line', 'sing', 'phrase', 'words', 'prose', 'music', 'chorus', 'refrain']
#
# Encoded word: dice
# Decoded: gamble
# Associates: ['game', 'gamble', 'roll', 'man', 'cards', 'throw', 'die', 'number', 'fuzzy', 'six', 'poker', 'square', 'dot', 'two', 'clay', 'bet', 'comedy', 'monopoly', 'snake']
#
# Encoded word: weapon
# Decoded: knife
# Associates: ['gun', 'knife', 'kill', 'war', 'danger', 'deadly', 'defend']
#
# Encoded word: blinds
# Decoded: drapes
# Associates: ['window', 'curtains', 'light', 'drapes', 'dark', 'sun', 'eye', 'see', 'glasses']
#
# Encoded word: blossom
# Decoded: bloom
# Associates: ['flower', 'show', 'bloom', 'grow', 'rose', 'orange', 'open', 'spring', 'cherry', 'mature', 'girl']
#
# Encoded word: architecture
# Decoded: design
# Associates: ['building', 'house', 'structure', 'design', 'build', 'wood', 'engineer', 'skyscraper', 'art', 'cathedral', 'drawing', 'draw']
#
# Encoded word: poem
# Decoded: song
# Associates: ['rhyme', 'love', 'song', 'english', 'romantic', 'beautiful', 'story', 'verse', 'beauty', 'read', 'poetry', 'poet', 'write', 'words', 'book', 'sonnet', 'art', 'prose', 'boring', 'literature', 'feeling', 'long', 'novel']
#
# Encoded word: chunk
# Decoded: slice
# Associates: ['piece', 'chocolate', 'block', 'fat', 'candy', 'rock', 'big', 'cheese', 'cookie', 'meat', 'part', 'mass', 'slice', 'huge', 'large', 'ice cream', 'food']
#
# Encoded word: casket
# Decoded: funeral
# Associates: ['death', 'dead', 'coffin', 'box', 'burial', 'funeral', 'basket', 'corpse']
#
# Encoded word: ascent
# Decoded: climb
# Associates: ['descent', 'climb', 'fall', 'up', 'rise', 'down', 'decline', 'mountain', 'stair', 'heaven', 'go', 'leave', 'raise', 'plane']
#
# Encoded word: sneakers
# Decoded: shoes
# Associates: ['shoes', 'run', 'smell', 'comfortable', 'white', 'feet', 'dirty', 'socks', 'movie']
#
# Encoded word: thief
# Decoded: robber
# Associates: ['steal', 'robber', 'crook', 'burglar', 'police', 'crime', 'criminal', 'night', 'take', 'money', 'bad']
#
# Encoded word: value
# Decoded: cost
# Associates: ['money', 'worth', 'price', 'morals', 'cost', 'expensive', 'deal', 'cheap', 'possession', 'bargain', 'priceless', 'buy', 'ethics', 'save', 'amount', 'dollar', 'true']
#
# Encoded word: whiskers
# Decoded: hair
# Associates: ['beard', 'cat', 'shave', 'hair', 'mustache', 'scratch', 'face', 'kitten']
#
# Encoded word: breakfast
# Decoded: meal
# Associates: ['lunch', 'dinner', 'egg', 'morning', 'cereal', 'food', 'meal', 'club', 'beginning', 'pancakes']
#
# Encoded word: biologist
# Decoded: scientist
# Associates: ['science', 'scientist', 'chemist', 'plant', 'marine', 'biology', 'doctor', 'lab', 'cell', 'teacher', 'study', 'animal', 'frog', 'experiment', 'life', 'water', 'bug', 'smart', 'boring', 'school', 'microscope']
#
# Encoded word: before
# Decoded: after
# Associates: ['after', 'yesterday']
#
# Encoded word: tuba
# Decoded: flute
# Associates: ['instrument', 'music', 'band', 'horn', 'loud', 'saxophone', 'water', 'trumpet', 'bass', 'blow', 'diving', 'brass', 'flute', 'player', 'clarinet', 'trombone']
#
# Encoded word: low
# Decoded: high
# Associates: ['high', 'down', 'shallow', 'salt', 'under', 'life']
#
# Encoded word: quantity
# Decoded: amount
# Associates: ['amount', 'quality', 'number', 'many', 'lot', 'much', 'large', 'beaker', 'weight', 'sum', 'mass']
#
# Encoded word: ceramic
# Decoded: pottery
# Associates: ['pottery', 'tile', 'vase', 'bowl', 'breakable', 'glass', 'clay', 'porcelain', 'dish', 'statue', 'art', 'tray']
#
# Encoded word: cylinder
# Decoded: engine
# Associates: ['round', 'tube', 'can', 'car', 'cone', 'circle', 'engine', 'piston', 'container', 'science', 'test tube', 'rod', 'cube']
#
# Encoded word: quick
# Decoded: slow
# Associates: ['fast', 'slow', 'run', 'start', 'silver', 'speed', 'fox', 'easy', 'stop', 'hurry']
#
# Encoded word: dagger
# Decoded: sword
# Associates: ['knife', 'sword', 'stab', 'cloak', 'kill', 'weapon', 'fight', 'blood', 'blade', 'murder']
#
# Encoded word: soup
# Decoded: salad
# Associates: ['chicken', 'tomato', 'sandwich', 'hot', 'vegetables', 'bowl', 'food', 'broth', 'liquid', 'cracker', 'onion', 'spoon', 'noodles', 'water', 'can', 'stew', 'eat', 'salad', 'saucer', 'dinner', 'chowder', 'drink', 'mushroom', 'sick']
#
# Encoded word: heel
# Decoded: ankle
# Associates: ['shoe', 'foot', 'toe', 'dog', 'ankle', 'better', 'boy', 'stop', 'bandaid']
#
# Encoded word: sum
# Decoded: amount
# Associates: ['add', 'total', 'money', 'amount', 'difference', 'math', 'whole', 'answer', 'product', 'all', 'up']
#
# Encoded word: seafood
# Decoded: lobster
# Associates: ['fish', 'shrimp', 'lobster', 'crab', 'restaurant', 'food', 'cat', 'pasta', 'delicious', 'clam', 'oyster', 'smell', 'yuck', 'eat']
#
# Encoded word: mixture
# Decoded: blend
# Associates: ['cake', 'combination', 'blend', 'drink', 'solution', 'chemistry', 'mix', 'chemical', 'food', 'variety', 'alcohol', 'recipe', 'science', 'water', 'cook']
#
# Encoded word: advertisement
# Decoded: ad
# Associates: ['television', 'commercial', 'newspaper', 'magazine', 'billboard', 'product', 'sell', 'sale', 'sign', 'buy', 'ad', 'agency', 'car', 'article', 'picture', 'money', 'business']
# Encoded word: shame
# Decoded: regret
# Associates: ['guilt', 'bad', 'disgrace', 'doubt', 'embarrass', 'sorrow', 'hide', 'pity', 'blame', 'sorry', 'humiliate', 'wrong', 'regret', 'abuse', 'hurt']
#
# Encoded word: bison
# Decoded: moose
# Associates: ['buffalo', 'animal', 'bull', 'ox', 'big', 'cow', 'snake', 'moose', 'meat', 'indian']
#
# Encoded word: filthy
# Decoded: dirty
# Associates: ['dirty', 'rich', 'dirt', 'mess', 'bum', 'poor', 'clean']
#
# Encoded word: science
# Decoded: biology
# Associates: ['biology', 'fiction', 'art', 'math', 'psychology', 'chemistry', 'experiment', 'technology', 'knowledge', 'study', 'discipline', 'lab', 'discovery', 'scientist', 'fair', 'method', 'astronomy', 'hard']
#
# Encoded word: character
# Decoded: actor
# Associates: ['personality', 'person', 'play', 'actor', 'cartoon', 'act', 'player', 'witness', 'letter', 'figure', 'funny', 'fine', 'movie', 'book', 'story']
#
# Encoded word: joker
# Decoded: clown
# Associates: ['cards', 'clown', 'funny', 'laugh', 'wild', 'ace']
#
# Encoded word: more
# Decoded: most
# Associates: ['less', 'enough', 'plenty', 'greed', 'money', 'lot', 'most', 'need']
#
# Encoded word: ape
# Decoded: gorilla
# Associates: ['monkey', 'gorilla', 'man', 'hairy', 'animal', 'mammal', 'jungle', 'chimpanzee', 'primate']
#
# Encoded word: marble
# Decoded: stone
# Associates: ['floor', 'stone', 'ball', 'game', 'round', 'table', 'tile', 'glass', 'roll', 'rock', 'statue', 'hard', 'expensive', 'white', 'smooth', 'play', 'cake', 'desk', 'granite', 'cold']
#
# Encoded word: courageous
# Decoded: brave
# Associates: ['brave', 'strong', 'coward', 'hero', 'lion', 'daring', 'courage', 'wimp', 'superman']
#
# Encoded word: bandit
# Decoded: robber
# Associates: ['thief', 'robber', 'bad', 'criminal', 'outlaw', 'crook', 'pirate', 'dog', 'mask', 'sheriff', 'raccoon', 'black', 'burglar']
#
# Encoded word: mood
# Decoded: feeling
# Associates: ['feeling', 'bad', 'happy', 'swing', 'emotion', 'good', 'depressed', 'change', 'state', 'sad', 'personality', 'attitude', 'ring', 'expression', 'anger', 'temper']
#
# Encoded word: reason
# Decoded: cause
# Associates: ['why', 'excuse', 'logic', 'rhyme', 'explanation', 'think', 'because', 'purpose', 'answer', 'cause', 'none', 'thought', 'idea', 'good', 'action', 'fact', 'plan', 'intellect', 'justify', 'knowledge', 'season', 'talk', 'argument', 'truth', 'for']
#
# Encoded word: shift
# Decoded: change
# Associates: ['move', 'gear', 'change', 'car', 'work', 'stick', 'switch', 'weight', 'standard', 'drive']
#
# Encoded word: companion
# Decoded: lover
# Associates: ['friend', 'mate', 'lover', 'buddy', 'alone', 'spouse', 'girl', 'partner', 'dog', 'peer', 'husband']
#
# Encoded word: wrist
# Decoded: ankle
# Associates: ['watch', 'hand', 'arm', 'band', 'bracelet', 'ankle', 'finger']
#
# Encoded word: penny
# Decoded: coin
# Associates: ['nickel', 'money', 'dime', 'copper', 'dollar', 'quarter', 'coin', 'center', 'shine', 'luck']
#
# Encoded word: agony
# Decoded: pain
# Associates: ['pain', 'defeat', 'ecstasy', 'fear', 'misery', 'hurt', 'hate']
#
# Encoded word: sleeve
# Decoded: jacket
# Associates: ['shirt', 'arm', 'coat', 'cuff', 'short', 'long', 'dress', 'jacket', 'clothes', 'blouse']
#
# Encoded word: stress
# Decoded: pressure
# Associates: ['anxiety', 'tension', 'pressure', 'test', 'school', 'headache', 'work', 'strain', 'tired', 'worry', 'problem', 'nerves', 'pain', 'relax', 'anger', 'sweat', 'frustration', 'out', 'health', 'nervous', 'relief', 'reduce', 'scared']
#
# Encoded word: warrior
# Decoded: fighter
# Associates: ['fighter', 'soldier', 'battle', 'indian', 'fight', 'war', 'brave', 'shield', 'strong', 'rebel', 'kill', 'man']
#
# Encoded word: dangerous
# Decoded: reckless
# Associates: ['scary', 'harmful', 'safe', 'risk', 'road', 'hazard', 'careful', 'drugs', 'bad', 'deadly', 'trouble', 'reckless', 'caution', 'toy', 'adventurous', 'gun', 'difficult', 'motorcycle', 'easy', 'cliff']
#
# Encoded word: interstate
# Decoded: highway
# Associates: ['highway', 'road', 'car', 'traffic', 'travel', 'fast', 'freeway', 'drive']
#
# Encoded word: entry
# Decoded: enter
# Associates: ['exit', 'door', 'form', 'enter', 'blank', 'contest', 'level', 'write', 'in', 'list', 'rear', 'log', 'begin']
#
# Encoded word: bulb
# Decoded: lamp
# Associates: ['light', 'tulip', 'flower', 'bright', 'plant', 'lamp', 'round']
#
# Encoded word: tuxedo
# Decoded: gown
# Associates: ['prom', 'formal', 'suit', 'black', 'dress', 'wedding', 'tie', 'penguin', 'gown']
#
# Encoded word: cloud
# Decoded: sky
# Associates: ['sky', 'rain', 'white', 'nine', 'soft', 'fluffy', 'dark', 'cotton']
#
# Encoded word: sphinx
# Decoded: statue
# Associates: ['egypt', 'cat', 'pyramid', 'lion', 'animal', 'statue', 'riddle', 'snake', 'desert', 'monument', 'silver']
#
# Encoded word: siren
# Decoded: horn
# Associates: ['police', 'loud', 'ambulance', 'noisy', 'fire', 'emergency', 'sound', 'cop', 'alarm', 'engine', 'horn', 'accident', 'signal', 'car']
#
# Encoded word: aluminum
# Decoded: metal
# Associates: ['can', 'foil', 'metal', 'tin', 'recycle', 'siding', 'steel', 'silver']

# %% [markdown]
# Entailed word is an associate in less than 10% of cases:

# %%
counter/len(words_overlap)
# Out:
# 0.08745247148288973

# %% [markdown]
# One possible reason why there is such a small overlap in entailment predictions and free norms might be the dataset that is used for training of the model. SNLI dataset contains sentences which usually involve people doing certain actions, generated by captioning imges. The vocabulary gathered in that way does not contain many finesses arising in a discourse or a written piece of text. To alleviate this one could try training the model on a different data set.
#
# Another reason for this poor match might be the model architecture which is designed as to process syntax, something less relevant in free association norms. So, the second idea is to modify the model to train it on more co-occurrence data (although some people have strongly argued against the interpretation of associations as co-occurences in text).
